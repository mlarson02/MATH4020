# %%
import pandas as pd
import numpy as np

def append_column_of_ones(csv_file_path):
    # Read CSV file into a Pandas DataFrame
    dataframe = pd.read_csv(csv_file_path)

    # Append a column of '1's to the DataFrame
    dataframe['label'] = 1

    return dataframe

def append_column_of_zeros(csv_file_path):
    # Read CSV file into a Pandas DataFrame
    dataframe = pd.read_csv(csv_file_path)

    # Append a column of '1's to the DataFrame
    dataframe['label'] = 0

    return dataframe

# %%
# Signal

ms20GeVs5 = "csvs/ms20GeV_sine-5.csv"  
ms20GeVs5_df = append_column_of_ones(ms20GeVs5)

ms20GeVs6 = "csvs/ms20GeV_sine-6.csv"  
ms20GeVs6_df = append_column_of_ones(ms20GeVs6)

ms60GeVs6 = "csvs/ms60GeV_sine-6.csv"  
ms60GeVs6_df = append_column_of_ones(ms60GeVs6)

ms60GeVs7 = "csvs/ms60GeV_sine-7.csv"  
ms60GeVs7_df = append_column_of_ones(ms60GeVs7)

ms20GeVs5_CLD = "csvs/ms20GeV_sine-5_CLD.csv"  
ms20GeVs5_df_CLD = append_column_of_ones(ms20GeVs5_CLD)

ms20GeVs6_CLD = "csvs/ms20GeV_sine-6_CLD.csv"  
ms20GeVs6_df_CLD = append_column_of_ones(ms20GeVs6_CLD)

ms60GeVs6_CLD = "csvs/ms60GeV_sine-6_CLD.csv"  
ms60GeVs6_df_CLD = append_column_of_ones(ms60GeVs6_CLD)

ms60GeVs7_CLD = "csvs/ms60GeV_sine-7_CLD.csv"  
ms60GeVs7_df_CLD = append_column_of_ones(ms60GeVs7_CLD)

# Backgrounds

WW_back = "csvs/WW_back.csv"
WW_back_df = append_column_of_zeros(WW_back)

WW_back_CLD = "csvs/WW_back_CLD.csv"
WW_back_CLD_df = append_column_of_zeros(WW_back_CLD)

ZZ_back = "csvs/ZZ_back.csv"
ZZ_back_df = append_column_of_zeros(ZZ_back)

ZZ_back_CLD = "csvs/ZZ_back_CLD.csv"
ZZ_back_CLD_df = append_column_of_zeros(ZZ_back_CLD)

ZZ_back_W2023 = "csvs/ZZ_back_Winter2023.csv"
ZZ_back_W2023_df = append_column_of_zeros(ZZ_back_W2023)

ZH_back = "csvs/ZH_back.csv"
ZH_back_df = append_column_of_zeros(ZH_back)

ZH_back_CLD = "csvs/ZH_back_CLD.csv"
ZH_back_CLD_df = append_column_of_zeros(ZH_back_CLD)

# %%
display(ZH_back_CLD_df)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  \
# 0            29                     27
# 1            31                     22
# 2            38                     36
# 3            52                     40
# 4            39                     19
# ...         ...                    ...
# 99995        33                     19
# 99996        24                      9
# 99997        24                     20
# 99998        32                     22
# 99999         6                      1
#
#                                  RecoParticleTrack_absD0  \
# 0      [1.3534202e-01 1.0829352e-02 5.5793121e-02 2.0...
# 1      [3.8153257e-03 2.5961992e-01 2.8639373e-01 7.7...
# 2      [4.5443673e-02 8.3327711e-02 1.0684580e-01 8.0...
# 3      [7.6470748e-02 4.8953397e-03 6.1894977e-03 5.4...
# 4      [9.05396044e-02 2.25087162e-02 1.62301387e-03 ...
# ...                                                  ...
# 99995  [1.6466057e+01 1.2920789e+01 2.0125431e-03 1.9...
# ...

# %%
display(ZH_back_df)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  n_seltracks_DVs  \
# 0            32                     27                0
# 1            35                     29                0
# 2            38                     29                0
# 3            46                     41                0
# 4            40                     34                0
# ...         ...                    ...              ...
# 99995        63                     31                0
# 99996        67                     59                0
# 99997        28                     21                0
# 99998        52                     46                0
# 99999        48                     30                0
#
#                                                RecoJet_e  \
# 0      [18.306257   4.465005   4.6701217  4.9114847  ...
# 1      [11.729151   4.4180074  4.9872155  2.6390772  ...
# 2      [3.9497979 4.5092115 2.642303  5.2142696 2.636...
# 3      [16.734196  14.406544  25.346848   9.403425   ...
# ...

# %%
def filter_dataframe(df):
    """
    Filter DataFrame based on specified conditions.

    Parameters:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: Filtered DataFrame containing rows that pass all conditions.
    """
    # Define conditionals based on column values
    conditional1 = (df['n_RecoElectrons'] >= 2) | (df['n_RecoMuons'] >= 2)
    conditional2 = (df['Reco_ee_invMass'].between(70, 110)) | (df['Reco_mumu_invMass'].between(70, 110))

    # Combine conditionals using logical AND
    combined_mask = conditional1 & conditional2

    # Filter DataFrame based on combined mask
    filtered_df = df[combined_mask]
   
    indices_to_remove = list(range(33, 51))
    df_filtered2 = filtered_df.drop(filtered_df.columns[indices_to_remove], axis=1)
    indices_to_remove2 = list(range(3,23)) # remove jet params 
    df_filtered3 = df_filtered2.drop(df_filtered2.columns[indices_to_remove2], axis=1)
    
    return df_filtered3

# %%
def filter_dataframe_NEW(df):
    """
    Filter DataFrame based on specified conditions.

    Parameters:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: Filtered DataFrame containing rows that pass all conditions.
    """
    # Define conditionals based on column values
    conditional1 = (df['n_RecoElectrons'] >= 2) | (df['n_RecoMuons'] >= 2)
    conditional2 = (df['Reco_ee_invMass'].between(70, 110)) | (df['Reco_mumu_invMass'].between(70, 110))

    # Combine conditionals using logical AND
    combined_mask = conditional1 & conditional2

    # Filter DataFrame based on combined mask
    filtered_df = df[combined_mask]
   
    indices_to_remove = list(range(13, 31))
    df_filtered2 = filtered_df.drop(filtered_df.columns[indices_to_remove], axis=1)
    
    return df_filtered2

# %%
def filter_dataframe_NEW2(df):
    """
    Filter DataFrame based on specified conditions.

    Parameters:
        df (pd.DataFrame): The DataFrame to filter.

    Returns:
        pd.DataFrame: Filtered DataFrame containing rows that pass all conditions.
    """
    # Define conditionals based on column values
    conditional1 = (df['n_RecoElectrons'] >= 2) | (df['n_RecoMuons'] >= 2)
    conditional2 = (df['Reco_ee_invMass'].between(70, 110)) | (df['Reco_mumu_invMass'].between(70, 110))

    # Combine conditionals using logical AND
    combined_mask = conditional1 & conditional2

    # Filter DataFrame based on combined mask
    filtered_df = df[combined_mask]
   
    indices_to_remove = list(range(12, 30))
    df_filtered2 = filtered_df.drop(filtered_df.columns[indices_to_remove], axis=1)
    
    return df_filtered2

# %%
cut_ms20GeVs5_df = filter_dataframe(ms20GeVs5_df)
cut_ms20GeVs6_df = filter_dataframe(ms20GeVs6_df)
cut_ms60GeVs6_df = filter_dataframe(ms60GeVs6_df)
cut_ms60GeVs7_df = filter_dataframe(ms60GeVs7_df) 

cut_ms20GeVs5_df_CLD = filter_dataframe(ms20GeVs5_df_CLD)
cut_ms20GeVs6_df_CLD = filter_dataframe(ms20GeVs6_df_CLD)
cut_ms60GeVs6_df_CLD = filter_dataframe(ms60GeVs6_df_CLD)
cut_ms60GeVs7_df_CLD = filter_dataframe(ms60GeVs7_df_CLD)

cut_WW_df = filter_dataframe(WW_back_df)
cut_WW_CLD_df = filter_dataframe_NEW(WW_back_CLD_df)
cut_ZZ_df = filter_dataframe(ZZ_back_df)
cut_ZZ_W2023_df = filter_dataframe_NEW(ZZ_back_W2023_df)
cut_ZZ_CLD_df = filter_dataframe_NEW(ZZ_back_CLD_df)
cut_ZH_df = filter_dataframe(ZH_back_df)
cut_ZH_CLD_df = filter_dataframe_NEW2(ZH_back_CLD_df)

# %%
display(cut_ZH_CLD_df)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  \
# 10           19                     16
# 73           20                     11
# 104          44                     33
# 110          11                     10
# 126          33                     23
# ...         ...                    ...
# 99834        33                     17
# 99841        19                     16
# 99887        18                      6
# 99889        11                      8
# 99932         6                      2
#
#                                  RecoParticleTrack_absD0  \
# 10     [2.8309816e-02 9.6304016e-03 1.7393689e-03 1.1...
# 73     [7.8717776e-02 3.6580421e-03 3.2169724e-01 1.1...
# 104    [2.5687411e-01 5.8658677e-04 1.8211615e-01 1.4...
# 110    [6.8933084e-03 8.3986614e-03 1.0751709e-02 9.0...
# 126    [3.13076787e-02 1.85007397e-02 6.77097589e-03 ...
# ...                                                  ...
# 99834  [4.0453970e-03 1.8239612e-02 1.5692091e-01 5.1...
# ...

# %%
def calculate_max(entry):
    # Check if entry is a string
    if isinstance(entry, str):
        # Remove leading and trailing brackets, split the string by spaces, and convert to list of floats
        entry_list = [float(value) for value in entry.strip('[]').split()]
        # Calculate the average if the list is not empty
        if entry_list:
            return max(entry_list)#sum(entry_list) / len(entry_list)
        else:
            return 0  # Return '0' if the list is empty
    elif isinstance(entry, list):
        # Calculate the average of the list
        if entry:
            return max(entry_list)#sum(entry) / len(entry)
        else:
            return 0  # Return '0' if the list is empty
    else:
        return entry  # Return the entry unchanged if it's not a list or string

# %%
def avg_columns(df, column_indices):
    df.iloc[:, column_indices] = df.iloc[:, column_indices].map(calculate_max)
    df = df.drop(columns=['RecoParticleTrack_absZ0sig'])
    df = df.drop(columns=['n_seltracks_DVs'])
    for column in df.columns:
        if df[column].dtype == 'object':
            try:
                df[column] = pd.to_numeric(df[column], errors='coerce')
            except ValueError:
                print(f"Unable to convert column '{column}' to numeric.")
    return df

# %%
def avg_columns2(df, column_indices):
    df.iloc[:, column_indices] = df.iloc[:, column_indices].map(calculate_max)
    df = df.drop(columns=['RecoParticleTrack_absZ0sig'])
    for column in df.columns:
        if df[column].dtype == 'object':
            try:
                df[column] = pd.to_numeric(df[column], errors='coerce')
            except ValueError:
                print(f"Unable to convert column '{column}' to numeric.")
    return df

# %%
column_indices = list(range(3, 13))
column_indices2 = list(range(2, 12))
cut_ms20GeVs5_df_final = avg_columns(cut_ms20GeVs5_df, column_indices)
cut_ms20GeVs6_df_final = avg_columns(cut_ms20GeVs6_df, column_indices)
cut_ms60GeVs6_df_final = avg_columns(cut_ms60GeVs6_df, column_indices)
cut_ms60GeVs7_df_final = avg_columns(cut_ms60GeVs7_df, column_indices)

cut_ms20GeVs5_df_final_CLD = avg_columns(cut_ms20GeVs5_df_CLD, column_indices)
cut_ms20GeVs6_df_final_CLD = avg_columns(cut_ms20GeVs6_df_CLD, column_indices)
cut_ms60GeVs6_df_final_CLD = avg_columns(cut_ms60GeVs6_df_CLD, column_indices)
cut_ms60GeVs7_df_final_CLD = avg_columns(cut_ms60GeVs7_df_CLD, column_indices)

cut_ZH_df_plot = avg_columns(ZH_back_df, column_indices)

cut_WW_df_final = avg_columns(cut_WW_df, column_indices)
cut_WW_CLD_df_final = avg_columns(cut_WW_CLD_df, column_indices)
cut_ZZ_df_final = avg_columns(cut_ZZ_df, column_indices)
cut_ZZ_CLD_df_final = avg_columns(cut_ZZ_CLD_df, column_indices)
cut_ZH_df_final = avg_columns(cut_ZH_df, column_indices)
cut_ZH_CLD_df_final = avg_columns2(cut_ZH_CLD_df, column_indices2)

# %%
display(cut_ZH_CLD_df_final)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  RecoParticleTrack_absD0  \
# 10           19                     16                 9.000000
# 73           20                     11                 9.000000
# 104          44                     33                16.340685
# 110          11                     10                 9.000000
# 126          33                     23                 9.000000
# ...         ...                    ...                      ...
# 99834        33                     17                82.072372
# 99841        19                     16                 9.000000
# 99887        18                      6                 9.000000
# 99889        11                      8                 9.000000
# 99932         6                      2                 9.000000
#
#        RecoParticleTrack_absZ0  RecoParticleTrack_absD0sig  \
# 10                     9.00000                   37.317459
# 73                     9.00000                   65.740640
# ...

# %%
display(cut_ms60GeVs7_df_final)
# Out:
#       n_tracks  n_RecoedPrimaryTracks  RecoParticleTrack_absD0  \
# 2            2                      1                 9.000000
# 4           15                      3              5387.633300
# 5           30                      2              1846.576300
# 6           24                      2               503.745610
# 7           36                      2              1947.330900
# ...        ...                    ...                      ...
# 9993         2                      1                 0.002835
# 9994        36                      2                99.854515
# 9995         9                      2               709.534910
# 9996        30                      2               727.416140
# 9997        38                      2              1630.960700
#
#       RecoParticleTrack_absZ0  RecoParticleTrack_absD0sig  \
# 2                    9.000000                     9.00000
# 4                61299.738000                  6963.58010
# ...

# %%
#cut_ms20GeVs5_df_final.describe()
cut_ms60GeVs6_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8947 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   n_tracks                                   8947 non-null   int64
#  1   n_RecoedPrimaryTracks                      8947 non-null   int64
#  2   RecoParticleTrack_absD0                    8947 non-null   float64
#  3   RecoParticleTrack_absZ0                    8947 non-null   float64
#  4   RecoParticleTrack_absD0sig                 8947 non-null   float64
#  5   RecoParticleTrack_D0cov                    8947 non-null   float64
#  6   RecoParticleTrack_Z0cov                    8947 non-null   float64
#  7   RecoParticleTrack_phi                      8947 non-null   float64
#  8   RecoParticleTrack_phi_cov                  8947 non-null   float64
#  9   RecoParticleTrack_getRP2TRK_tanLambda      8947 non-null   float64
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
cut_ms60GeVs7_df_final_CLD.hist(bins=50, figsize=(40,30))
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
cut_ms60GeVs7_df_final.hist(bins=50, figsize=(40,30))
plt.show()

# %%
cut_WW_df_final.hist(bins=50, figsize=(40,30))
plt.show()
# overlay background and signal plots

# %%
cut_ZZ_df_final.hist(bins=50, figsize=(40,30))
plt.show()
# overlay background and signal plots

# %%
cut_ZH_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4708 entries, 14 to 99994
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   n_tracks                                   4708 non-null   int64
#  1   n_RecoedPrimaryTracks                      4708 non-null   int64
#  2   RecoParticleTrack_absD0                    4708 non-null   float64
#  3   RecoParticleTrack_absZ0                    4708 non-null   float64
#  4   RecoParticleTrack_absD0sig                 4708 non-null   float64
#  5   RecoParticleTrack_D0cov                    4708 non-null   float64
#  6   RecoParticleTrack_Z0cov                    4708 non-null   float64
#  7   RecoParticleTrack_phi                      4708 non-null   float64
#  8   RecoParticleTrack_phi_cov                  4708 non-null   float64
#  9   RecoParticleTrack_getRP2TRK_tanLambda      4708 non-null   float64
# ...

# %%
cut_ZH_df_final.hist(bins=50, figsize=(40,30))
plt.show()
# overlay background and signal plots

# %%
display(cut_ZH_CLD_df_final)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  RecoParticleTrack_absD0  \
# 10           19                     16                 9.000000
# 73           20                     11                 9.000000
# 104          44                     33                16.340685
# 110          11                     10                 9.000000
# 126          33                     23                 9.000000
# ...         ...                    ...                      ...
# 99834        33                     17                82.072372
# 99841        19                     16                 9.000000
# 99887        18                      6                 9.000000
# 99889        11                      8                 9.000000
# 99932         6                      2                 9.000000
#
#        RecoParticleTrack_absZ0  RecoParticleTrack_absD0sig  \
# 10                     9.00000                   37.317459
# 73                     9.00000                   65.740640
# ...

# %%
cut_WW_df_final.describe()
# Out:
#          n_tracks  n_RecoedPrimaryTracks  RecoParticleTrack_absD0  \
# count  569.000000             569.000000               569.000000
# mean     2.003515               1.003515                 4.203142
# std      0.083844               0.083844                 4.482662
# min      2.000000               1.000000                 0.000340
# 25%      2.000000               1.000000                 0.006966
# 50%      2.000000               1.000000                 0.092595
# 75%      2.000000               1.000000                 9.000000
# max      4.000000               3.000000                 9.000000
#
#        RecoParticleTrack_absZ0  RecoParticleTrack_absD0sig  \
# count               569.000000                  569.000000
# mean                  4.454705                   10.851494
# std                   4.256315                   14.527557
# min                   0.000609                    0.145311
# 25%                   0.370975                    3.239147
# ...

# %%
print(len(cut_WW_df_final) + (len(cut_ZH_df)) + len(cut_ZZ_df_final))
# Out:
# 13892

# %%
print(len(cut_WW_CLD_df_final) + (len(cut_ZH_CLD_df_final)) + len(cut_ZZ_CLD_df_final))
# Out:
# 14022

# %%
# concatenate background and signals together

data_ms20s5 = pd.concat([cut_ms20GeVs5_df_final, cut_WW_df_final, cut_ZH_df_final, cut_ZZ_df_final], ignore_index=True)
data_ms20s5_CLD = pd.concat([cut_ms20GeVs5_df_final_CLD, cut_WW_CLD_df_final, cut_ZH_CLD_df_final, cut_ZZ_CLD_df_final], ignore_index=True)
data_ms20s6 = pd.concat([cut_ms20GeVs6_df_final, cut_WW_df_final, cut_ZH_df_final, cut_ZZ_df_final], ignore_index=True)
data_ms20s6_CLD = pd.concat([cut_ms20GeVs6_df_final_CLD, cut_WW_CLD_df_final, cut_ZH_CLD_df_final, cut_ZZ_CLD_df_final], ignore_index=True)
data_ms60s6 = pd.concat([cut_ms60GeVs6_df_final, cut_WW_df_final, cut_ZH_df_final, cut_ZZ_df_final], ignore_index=True)
data_ms60s6_CLD = pd.concat([cut_ms60GeVs6_df_final_CLD, cut_WW_CLD_df_final, cut_ZH_CLD_df_final, cut_ZZ_CLD_df_final], ignore_index=True)
data_ms60s7 = pd.concat([cut_ms60GeVs7_df_final, cut_WW_df_final, cut_ZH_df_final, cut_ZZ_df_final], ignore_index=True)
data_ms60s7_CLD = pd.concat([cut_ms60GeVs7_df_final_CLD, cut_WW_CLD_df_final, cut_ZH_CLD_df_final, cut_ZZ_CLD_df_final], ignore_index=True)
#data_ms20s5.describe()
display(data_ms20s5_CLD)
# Out:
#        n_tracks  n_RecoedPrimaryTracks  RecoParticleTrack_absD0  \
# 0            25                      2                 9.000000
# 1            26                      2                29.733028
# 2            23                      2                21.723665
# 3            20                      2                 9.000000
# 4            31                      2                 9.000000
# ...         ...                    ...                      ...
# 22927        12                     11                 9.000000
# 22928        21                     19                12.222846
# 22929        40                     27               203.947920
# 22930        16                     10                45.576122
# 22931        31                     21               110.199829
#
#        RecoParticleTrack_absZ0  RecoParticleTrack_absD0sig  \
# 0                     9.000000                  581.834050
# 1                    57.979816                  129.696010
# ...

# %%
# split to x_train, x_test, y_train, y_test
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# split each DF 

X1 = data_ms20s5.iloc[:, :-1]
y1 = data_ms20s5.iloc[:, -1]  # Select the last column as y
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.5) # check to make sure random

X1_C = data_ms20s5_CLD.iloc[:, :-1]
y1_C = data_ms20s5_CLD.iloc[:, -1]  # Select the last column as y
X_train1_C, X_test1_C, y_train1_C, y_test1_C = train_test_split(X1_C, y1_C, test_size=0.5) # check to make sure random

X2 = data_ms20s6.iloc[:, :-1]
y2 = data_ms20s6.iloc[:, -1]  # Select the last column as y
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.5)

X2_C = data_ms20s6_CLD.iloc[:, :-1]
y2_C = data_ms20s6_CLD.iloc[:, -1]  # Select the last column as y
X_train2_C, X_test2_C, y_train2_C, y_test2_C = train_test_split(X2_C, y2_C, test_size=0.5) # check to make sure random

X3 = data_ms60s6.iloc[:, :-1]
y3 = data_ms60s6.iloc[:, -1]  # Select the last column as y
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.5)

X3_C = data_ms60s6_CLD.iloc[:, :-1]
y3_C = data_ms60s6_CLD.iloc[:, -1]  # Select the last column as y
X_train3_C, X_test3_C, y_train3_C, y_test3_C = train_test_split(X3_C, y3_C, test_size=0.5) # check to make sure random

X4 = data_ms60s7.iloc[:, :-1]
y4 = data_ms60s7.iloc[:, -1]  # Select the last column as y
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.5)

X4_C = data_ms60s7_CLD.iloc[:, :-1]
y4_C = data_ms60s7_CLD.iloc[:, -1]  # Select the last column as y
X_train4_C, X_test4_C, y_train4_C, y_test4_C = train_test_split(X4_C, y4_C, test_size=0.5) # check to make sure random

# %%
### LOGISTIC REGRESSION


from sklearn.linear_model import LogisticRegression

# ms 20 gev sine-5 IDEA then CLD

clf1 = LogisticRegression(max_iter=1000)
clf1.fit(X_train1,y_train1)
print("Logistic Regression Score Signal 1: %.3f"%clf1.score(X_test1,y_test1))
column_names = X1.columns.tolist()
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf1.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf1.intercept_)
'''
clf1_C = LogisticRegression(max_iter=1000)
clf1_C.fit(X_train1_C,y_train1_C)
print("Logistic Regression Score Signal 1, CLD: %.3f"%clf1_C.score(X_test1_C,y_test1_C))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf1_C.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf1_C.intercept_)
'''
# ms 20 gev sine-6 IDEA then CLD

clf2 = LogisticRegression(max_iter=1000)
clf2.fit(X_train2,y_train2)
print("Logistic Regression Score Signal 2: %.3f"%clf2.score(X_test2,y_test2))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf2.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf2.intercept_)
'''
clf2_C = LogisticRegression(max_iter=1000)
clf2_C.fit(X_train2_C,y_train2_C)
print("Logistic Regression Score Signal 2, CLD: %.3f"%clf2_C.score(X_test1_C,y_test1_C))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf2_C.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf2_C.intercept_)
'''
# ms 60 gev sine-6 IDEA then CLD

clf3 = LogisticRegression(max_iter=1000)
clf3.fit(X_train3,y_train3)
print("Logistic Regression Score Signal 3: %.3f"%clf3.score(X_test3,y_test3))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf3.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf3.intercept_)
'''
clf3_C = LogisticRegression(max_iter=1000)
clf3_C.fit(X_train3_C,y_train3_C)
print("Logistic Regression Score Signal 3, CLD: %.3f"%clf3_C.score(X_test3_C,y_test3_C))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf3_C.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf3_C.intercept_)
'''
# ms 60 gev sine-7 IDEA then CLD

clf4 = LogisticRegression(max_iter=1000)
clf4.fit(X_train4,y_train4)
print("Logistic Regression Score Signal 4: %.3f"%clf4.score(X_test4,y_test4))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf4.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf4.intercept_)
'''
clf4_C = LogisticRegression(max_iter=1000)
clf4_C.fit(X_train4_C,y_train4_C)
print("Logistic Regression Score Signal 4, CLD: %.3f"%clf4_C.score(X_test4_C,y_test4_C))
'''
print("Coefficients:")
for feature, coef in zip(column_names, clf4_C.coef_[0]):
    print(f"{feature}: {coef}")
print("Intercept:", clf4_C.intercept_)
'''
# Out:
# Logistic Regression Score Signal 1: 0.998
# Logistic Regression Score Signal 1, CLD: 0.995
# Logistic Regression Score Signal 2: 0.992
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Score Signal 2, CLD: 0.934
# Logistic Regression Score Signal 3: 0.999
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

#Pipeline(steps=[('standardscaler', StandardScaler()),('svc', SVC(gamma='auto'))])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC.fit(X_train1, y_train1)
y_predict1_SVC = clf_SVC.predict(X_test1)

conf_mx1_SVC = confusion_matrix(y_test1, y_predict1_SVC) / len(y_test1)
conf_mx1_SVC
# Out:
# array([[0.61183806, 0.00149293],
#        [0.00061474, 0.38605427]])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC_C = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC_C.fit(X_train1_C, y_train1_C)
y_predict1_SVC_C = clf_SVC_C.predict(X_test1_C)

conf_mx1_SVC_C = confusion_matrix(y_test1_C, y_predict1_SVC_C) / len(y_test1_C)
conf_mx1_SVC_C
# Out:
# array([[0.60875632, 0.00148264],
#        [0.00357579, 0.38618524]])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC2 = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC2.fit(X_train2, y_train2)
y_predict2_SVC = clf_SVC2.predict(X_test2)

conf_mx1_SVC2 = confusion_matrix(y_test2, y_predict2_SVC) / len(y_test2)
conf_mx1_SVC2
# Out:
# array([[0.60572532, 0.00201967],
#        [0.00605901, 0.386196  ]])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC2_C = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC2_C.fit(X_train2_C, y_train2_C)
y_predict2_SVC_C = clf_SVC_C.predict(X_test2_C)

conf_mx1_SVC2_C = confusion_matrix(y_test2_C, y_predict2_SVC_C) / len(y_test2_C)
conf_mx1_SVC2_C
# Out:
# array([[0.61002349, 0.0018272 ],
#        [0.29104672, 0.09710258]])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC3 = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC3.fit(X_train3, y_train3)
y_predict3_SVC = clf_SVC3.predict(X_test3)

conf_mx1_SVC3 = confusion_matrix(y_test3, y_predict3_SVC) / len(y_test3)
conf_mx1_SVC3
# Out:
# array([[6.08931699e-01, 6.12959720e-04],
#        [5.25394046e-04, 3.89929947e-01]])

# %%
from sklearn.metrics import confusion_matrix
clf_SVC3_C = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf_SVC3_C.fit(X_train3_C, y_train3_C)
y_predict3_SVC_C = clf_SVC3_C.predict(X_test3_C)

conf_mx1_SVC3_C = confusion_matrix(y_test3_C, y_predict3_SVC_C) / len(y_test3_C)
conf_mx1_SVC3_C
# Out:
# array([[0.60859355, 0.00078281],
#        [0.00139167, 0.38923197]])

# %%
clf_SVC4 = make_pipeline(StandardScaler(), SVC(gamma='auto')) # try different kernels 
clf_SVC4.fit(X_train4, y_train4)
from sklearn.metrics import confusion_matrix
y_predict4_SVC = clf_SVC4.predict(X_test4) 

conf_mx4_SVC = confusion_matrix(y_test4, y_predict4_SVC) / len(y_test4)
conf_mx4_SVC

# try lda, qda (qda should be better)
# Out:
# array([[0.58351562, 0.02064923],
#        [0.09213404, 0.30370111]])

# %%
clf_SVC4_p = make_pipeline(StandardScaler(), SVC(gamma='auto', kernel="poly", degree=1)) # try different kernels 
clf_SVC4_p.fit(X_train4, y_train4)
from sklearn.metrics import confusion_matrix
y_predict4_SVC = clf_SVC4_p.predict(X_test4) 

conf_mx4_SVC_p = confusion_matrix(y_test4, y_predict4_SVC) / len(y_test4)
conf_mx4_SVC_p

# try lda, qda (qda should be better)
# Out:
# array([[0.59961501, 0.00454983],
#        [0.1094584 , 0.28637676]])

# %%
clf_SVC4_c_p = make_pipeline(StandardScaler(), SVC(gamma='auto', kernel="poly", degree=1))#, degree=2)) # try different kernels 
clf_SVC4_c_p.fit(X_train4_C, y_train4_C)
from sklearn.metrics import confusion_matrix
y_predict4_SVC_C = clf_SVC4_c_p.predict(X_test4_C) 

conf_mx4_SVC_p_C = confusion_matrix(y_test4_C, y_predict4_SVC_C) / len(y_test4_C)
conf_mx4_SVC_p_C

# try lda, qda (qda should be better)
# Out:
# array([[0.49009385, 0.12061175],
#        [0.00069517, 0.38859924]])

# %%
from sklearn.metrics import confusion_matrix
y_predict1 = clf1.predict(X_test1)
conf_mx1 = confusion_matrix(y_test1, y_predict1) / len(y_test1)
conf_mx1
# Out:
# array([[0.61192588, 0.00140511],
#        [0.00096601, 0.38570299]])

# %%
from sklearn.metrics import confusion_matrix
y_predict1_C = clf1_C.predict(X_test1_C)
conf_mx1_C = confusion_matrix(y_test1_C, y_predict1_C) / len(y_test1_C)
conf_mx1_C
# Out:
# array([[0.60875632, 0.00148264],
#        [0.00340136, 0.38635967]])

# %%
from sklearn.metrics import confusion_matrix
y_predict2 = clf2.predict(X_test2)
conf_mx2 = confusion_matrix(y_test2, y_predict2) / len(y_test2)
conf_mx2
# Out:
# array([[0.60607657, 0.00166842],
#        [0.00614682, 0.38610818]])

# %%
from sklearn.metrics import confusion_matrix
y_predict2_C = clf2_C.predict(X_test2_C)
conf_mx2_C = confusion_matrix(y_test2_C, y_predict2_C) / len(y_test2_C)
conf_mx2_C
# Out:
# array([[0.559645  , 0.05220569],
#        [0.0073088 , 0.38084051]])

# %%
from sklearn.metrics import confusion_matrix
y_predict3 = clf3.predict(X_test3)
conf_mx3 = confusion_matrix(y_test3, y_predict3) / len(y_test3)
conf_mx3
# Out:
# array([[6.09019264e-01, 5.25394046e-04],
#        [6.12959720e-04, 3.89842382e-01]])

# %%
from sklearn.metrics import confusion_matrix
y_predict3_C = clf3_C.predict(X_test3_C)
conf_mx3_C = confusion_matrix(y_test3_C, y_predict3_C) / len(y_test3_C)
conf_mx3_C
# Out:
# array([[0.60841959, 0.00095677],
#        [0.00226146, 0.38836218]])

# %%
from sklearn.metrics import confusion_matrix
y_predict4 = clf4.predict(X_test4)
conf_mx4 = confusion_matrix(y_test4, y_predict4) / len(y_test4)
conf_mx4
# Out:
# array([[0.54527955, 0.05888529],
#        [0.04409835, 0.35173681]])

# %%
from sklearn.metrics import confusion_matrix
y_predict4_C = clf4_C.predict(X_test4_C)
conf_mx4_C = confusion_matrix(y_test4_C, y_predict4_C) / len(y_test4_C)
conf_mx4_C
# Out:
# array([[0.50503997, 0.10566562],
#        [0.00191171, 0.38738269]])

# %%
import seaborn as sns
#row_sum = conf_mx1.sum(axis=1, keepdims=True)
#nconf_mx = conf_mx1/row_sum
#np.fill_diagonal(nconf_mx,0)

#sns.heatmap(nconf_mx)

# %%
### NEURAL NETWORK
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, callbacks
keras.backend.clear_session()
np.random.seed(32)
tf.random.set_seed(32)

print(X_train1.shape)
# Out:
# (11386, 11)

# %%
model1 = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model1_C = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model1_C.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model2 = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model2_C = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model2_C.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model3 = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model3_C = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model3_C.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model4 = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model4.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model4_C = Sequential([
    layers.Dense(64, activation='relu', input_shape=(11,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model4_C.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,981 (58.52 KB)
#  Trainable params: 4,993 (19.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 9,988 (39.02 KB)

# %%
# Train the model
model1.fit(X_train1, y_train1, epochs=25, batch_size=31)

# Evaluate the model
loss, accuracy = model1.evaluate(X_test1, y_test1)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Epoch 1/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6818 - loss: 5.6376
# Epoch 2/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9252 - loss: 1.0299
# Epoch 3/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9744 - loss: 0.1620
# Epoch 4/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9768 - loss: 0.1147
# Epoch 5/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9176 - loss: 2.2157
# Epoch 6/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9931 - loss: 0.0339
# Epoch 7/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.9708 - loss: 0.3067
# Epoch 8/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.9900 - loss: 0.0685
# Epoch 9/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.9908 - loss: 0.0602
# Epoch 10/25
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9837 - loss: 0.1734
# Epoch 11/25
# ...

# %%
# Train the model
model1_C.fit(X_train1_C, y_train1_C, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model1_C.evaluate(X_test1_C, y_test1_C)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Epoch 1/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.7192 - loss: 3.3810
# Epoch 2/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9394 - loss: 0.5039
# Epoch 3/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.9307 - loss: 1.1965
# Epoch 4/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9451 - loss: 0.6904
# Epoch 5/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9606 - loss: 0.7849
# Epoch 6/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.9794 - loss: 0.1890
# Epoch 7/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9589 - loss: 0.9554
# Epoch 8/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9729 - loss: 0.4414
# Epoch 9/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.9605 - loss: 1.0407
# Epoch 10/25
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9864 - loss: 0.1899
# Epoch 11/25
# ...

# %%
# Train the model
model2.fit(X_train2, y_train2, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model2.evaluate(X_test2, y_test2)
print(f'Test loss 2: {loss}')
print(f'Test accuracy 2: {accuracy}')
# Out:
# Epoch 1/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 1s 800us/step - accuracy: 0.7719 - loss: 225.1947
# Epoch 2/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.9685 - loss: 0.4331
# Epoch 3/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.9695 - loss: 0.6610
# Epoch 4/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9740 - loss: 0.4902
# Epoch 5/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9734 - loss: 0.5834
# Epoch 6/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9663 - loss: 0.9009
# Epoch 7/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.9752 - loss: 0.5409
# Epoch 8/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.9739 - loss: 0.6442
# Epoch 9/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9754 - loss: 0.5071
# Epoch 10/25
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9780 - loss: 0.4341
# Epoch 11/25
# ...

# %%
# Train the model
model2_C.fit(X_train2_C, y_train2_C, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model2_C.evaluate(X_test2_C, y_test2_C)
print(f'Test loss 2: {loss}')
print(f'Test accuracy 2: {accuracy}')
# Out:
# Epoch 1/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.7348 - loss: 1.8472
# Epoch 2/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.8788 - loss: 1.6365
# Epoch 3/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8993 - loss: 1.3464
# Epoch 4/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9082 - loss: 0.8251
# Epoch 5/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9182 - loss: 0.5785
# Epoch 6/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.9247 - loss: 0.3726
# Epoch 7/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9266 - loss: 0.5141
# Epoch 8/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9212 - loss: 0.5391
# Epoch 9/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9281 - loss: 0.4505
# Epoch 10/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9174 - loss: 0.6609
# Epoch 11/25
# ...

# %%
# Train the model
model3.fit(X_train3, y_train3, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model3.evaluate(X_test3, y_test3)
print(f'Test loss 3: {loss}')
print(f'Test accuracy 3: {accuracy}')
# Out:
# Epoch 1/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.7416 - loss: 14.9233
# Epoch 2/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8886 - loss: 2.0230
# Epoch 3/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9416 - loss: 0.9931
# Epoch 4/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9391 - loss: 1.1544
# Epoch 5/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9687 - loss: 0.4527
# Epoch 6/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9463 - loss: 1.3415
# Epoch 7/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.9690 - loss: 0.7993
# Epoch 8/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9701 - loss: 0.9306
# Epoch 9/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9743 - loss: 0.6376
# Epoch 10/25
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9769 - loss: 0.6675
# Epoch 11/25
# ...

# %%
# Train the model
model3_C.fit(X_train3_C, y_train3_C, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model3_C.evaluate(X_test3_C, y_test3_C)
print(f'Test loss 3: {loss}')
print(f'Test accuracy 3: {accuracy}')
# Out:
# Epoch 1/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - accuracy: 0.7398 - loss: 11.9273
# Epoch 2/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.8913 - loss: 4.3820
# Epoch 3/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9085 - loss: 5.6214
# Epoch 4/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9484 - loss: 1.1157
# Epoch 5/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.9630 - loss: 0.8302
# Epoch 6/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9728 - loss: 0.5118
# Epoch 7/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.9381 - loss: 3.3576
# Epoch 8/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9631 - loss: 1.7470
# Epoch 9/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9824 - loss: 0.2475
# Epoch 10/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9626 - loss: 2.0838
# Epoch 11/25
# ...

# %%
# Train the model
model4.fit(X_train4, y_train4, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model4.evaluate(X_test4, y_test4)
print(f'Test loss 4: {loss}')
print(f'Test accuracy 4: {accuracy}')
# Out:
# Epoch 1/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step - accuracy: 0.7507 - loss: 64.1124
# Epoch 2/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.8761 - loss: 5.8094
# Epoch 3/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.9205 - loss: 0.7079
# Epoch 4/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.9257 - loss: 0.7465
# Epoch 5/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 0.8956 - loss: 5.1783
# Epoch 6/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9245 - loss: 1.2244
# Epoch 7/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.9298 - loss: 0.8377
# Epoch 8/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9288 - loss: 1.1688
# Epoch 9/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.9234 - loss: 1.9356
# Epoch 10/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 0.9315 - loss: 1.0671
# Epoch 11/25
# ...

# %%
# Train the model
model4_C.fit(X_train4_C, y_train4_C, epochs=25, batch_size=32)

# Evaluate the model
loss, accuracy = model4_C.evaluate(X_test4_C, y_test4_C)
print(f'Test loss 4: {loss}')
print(f'Test accuracy 4: {accuracy}')
# Out:
# Epoch 1/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - accuracy: 0.7998 - loss: 7.2623
# Epoch 2/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9029 - loss: 1.0348
# Epoch 3/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.9129 - loss: 0.9081
# Epoch 4/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.9183 - loss: 0.7829
# Epoch 5/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9212 - loss: 0.8321
# Epoch 6/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9258 - loss: 0.7378
# Epoch 7/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9289 - loss: 0.5063
# Epoch 8/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.9314 - loss: 0.4718
# Epoch 9/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9294 - loss: 0.5528
# Epoch 10/25
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9301 - loss: 0.4995
# Epoch 11/25
# ...

# %%
# Predict classes for test set
y_probs1 = model1.predict(X_test1)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred1 = (y_probs1 > 0.5).astype(int)

# Generate confusion matrix
conf_matrix1 = confusion_matrix(y_test1, y_pred1) / len(y_test1)

print("Confusion Matrix:")
print(conf_matrix1)
# Out:
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# Confusion Matrix:
# [[0.61183806 0.00149293]
#  [0.00201985 0.38464916]]

# %%
# Predict classes for test set
y_probs1_C = model1_C.predict(X_test1_C)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred1_C = (y_probs1_C > 0.5).astype(int)

# Generate confusion matrix
conf_matrix1_C = confusion_matrix(y_test1_C, y_pred1_C) / len(y_test1_C)

print("Confusion Matrix:")
print(conf_matrix1_C)
# Out:
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step
# Confusion Matrix:
# [[0.60718646 0.0030525 ]
#  [0.004884   0.38487703]]

# %%
# Predict classes for test set
y_probs2 = model2.predict(X_test2)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred2 = (y_probs2 > 0.5).astype(int)

# Generate confusion matrix
conf_matrix2 = confusion_matrix(y_test2, y_pred2) / len(y_test2)

print("Confusion Matrix:")
print(conf_matrix2)
# Out:
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# Confusion Matrix:
# [[0.60388128 0.00386372]
#  [0.00667369 0.38558131]]

# %%
# Predict classes for test set
y_probs2_C = model2_C.predict(X_test2_C)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred2_C = (y_probs2_C > 0.5).astype(int)

# Generate confusion matrix
conf_matrix2_C = confusion_matrix(y_test2_C, y_pred2_C) / len(y_test2_C)

print("Confusion Matrix:")
print(conf_matrix2_C)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step
# Confusion Matrix:
# [[0.55955799 0.0522927 ]
#  [0.00817889 0.37997042]]

# %%
# Predict classes for test set
y_probs3 = model3.predict(X_test3)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred3 = (y_probs3 > 0.5).astype(int)

# Generate confusion matrix
conf_matrix3 = confusion_matrix(y_test3, y_pred3) / len(y_test3)

print("Confusion Matrix:")
print(conf_matrix3)
# Out:
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# Confusion Matrix:
# [[0.60647986 0.0030648 ]
#  [0.00078809 0.38966725]]

# %%
# Predict classes for test set
y_probs3_C = model3.predict(X_test3_C)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred3_C = (y_probs3_C > 0.5).astype(int)

# Generate confusion matrix
conf_matrix3_C = confusion_matrix(y_test3_C, y_pred3_C) / len(y_test3_C)

print("Confusion Matrix:")
print(conf_matrix3_C)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step
# Confusion Matrix:
# [[0.60720188 0.00217448]
#  [0.00295729 0.38766635]]

# %%
# Predict classes for test set
y_probs4 = model4.predict(X_test4)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred4 = (y_probs4 > 0.5).astype(int)

# Generate confusion matrix
conf_matrix4 = confusion_matrix(y_test4, y_pred4) / len(y_test4)

print("Confusion Matrix:")
print(conf_matrix4)
# Out:
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step
# Confusion Matrix:
# [[0.57117858 0.03298626]
#  [0.01977426 0.3760609 ]]

# %%
# Predict classes for test set
y_probs4_C = model4.predict(X_test4_C)

# Convert probabilities to binary labels using a threshold of 0.5
y_pred4_C = (y_probs4_C > 0.5).astype(int)

# Generate confusion matrix
conf_matrix4_C = confusion_matrix(y_test4_C, y_pred4_C) / len(y_test4_C)

print("Confusion Matrix:")
print(conf_matrix4_C)
# Out:
#   1/360 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step
# Confusion Matrix:
# [[0.57533889 0.0353667 ]
#  [0.07464373 0.31465068]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier1 = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier1.fit(X_train1, y_train1)

y_pred1_rf = rf_classifier1.predict(X_test1)


conf_matrix1_RF = confusion_matrix(y_test1, y_pred1_rf) / len(y_pred1_rf)

print("Confusion Matrix:")
print(conf_matrix1_RF)
print(rf_classifier1.feature_importances_)
# Out:
# Confusion Matrix:
# [[0.61271626 0.00061474]
#  [0.00070256 0.38596645]]
# [0.12436085 0.44071021 0.01466532 0.02460301 0.13400857 0.12908731
#  0.02989577 0.00182187 0.04821633 0.00202136 0.05060939]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier1_C = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier1_C.fit(X_train1_C, y_train1_C)

y_pred1_rf_C = rf_classifier1.predict(X_test1_C)


conf_matrix1_RF_C = confusion_matrix(y_test1_C, y_pred1_rf_C) / len(y_pred1_rf_C)

print("Confusion Matrix:")
print(conf_matrix1_RF_C)
print(rf_classifier1_C.feature_importances_)
# Out:
# Confusion Matrix:
# [[0.60866911 0.00156986]
#  [0.00697715 0.38278388]]
# [0.13541168 0.52824291 0.02142626 0.0150257  0.14147662 0.06610112
#  0.03257875 0.00368967 0.02446951 0.0045132  0.02706457]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier2 = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier2.fit(X_train2, y_train2)

y_pred2_rf = rf_classifier2.predict(X_test2)


conf_matrix2_RF = confusion_matrix(y_test2, y_pred2_rf) / len(y_pred2_rf)

print("Confusion Matrix:")
print(conf_matrix2_RF)
# Out:
# Confusion Matrix:
# [[0.6070425  0.00070249]
#  [0.00342466 0.38883035]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier2_C = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier2_C.fit(X_train2_C, y_train2_C)

y_pred2_rf_C = rf_classifier2_C.predict(X_test2_C)


conf_matrix2_RF_C = confusion_matrix(y_test2_C, y_pred2_rf_C) / len(y_pred2_rf_C)

print("Confusion Matrix:")
print(conf_matrix2_RF_C)
# Out:
# Confusion Matrix:
# [[0.568781   0.04306969]
#  [0.00234926 0.38580005]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier3 = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier3.fit(X_train3, y_train3)

y_pred3_rf = rf_classifier3.predict(X_test3)


conf_matrix3_RF = confusion_matrix(y_test3, y_pred3_rf) / len(y_pred3_rf)

print("Confusion Matrix:")
print(conf_matrix3_RF)
# Out:
# Confusion Matrix:
# [[6.09369527e-01 1.75131349e-04]
#  [8.75656743e-04 3.89579685e-01]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier3_C = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier3_C.fit(X_train3_C, y_train3_C)

y_pred3_rf_C = rf_classifier3_C.predict(X_test3_C)


conf_matrix3_RF_C = confusion_matrix(y_test3_C, y_pred3_rf_C) / len(y_pred3_rf_C)

print("Confusion Matrix:")
print(conf_matrix3_RF_C)
# Out:
# Confusion Matrix:
# [[0.60937636 0.        ]
#  [0.00104375 0.38957989]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier4 = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier4.fit(X_train4, y_train4)

y_pred4_rf = rf_classifier4.predict(X_test4)


conf_matrix4_RF = confusion_matrix(y_test4, y_pred4_rf) / len(y_pred4_rf)

print("Confusion Matrix:")
print(conf_matrix4_RF)
# Out:
# Confusion Matrix:
# [[0.59016537 0.01399948]
#  [0.00831219 0.38752297]]

# %%
# implement random forest

from sklearn.ensemble import RandomForestClassifier

rf_classifier4_C = RandomForestClassifier(n_estimators=100, criterion='log_loss')

rf_classifier4_C.fit(X_train4_C, y_train4_C)

y_pred4_rf_C = rf_classifier4_C.predict(X_test4_C)


conf_matrix4_RF_C = confusion_matrix(y_test4_C, y_pred4_rf_C) / len(y_pred4_rf_C)

print("Confusion Matrix:")
print(conf_matrix4_RF_C)
# Out:
# Confusion Matrix:
# [[0.56899548 0.04171011]
#  [0.0021724  0.387122  ]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier1 = GradientBoostingClassifier(n_estimators=100)

gb_classifier1.fit(X_train1, y_train1)

y_pred1_GB = gb_classifier1.predict(X_test1)

conf_matrix1_GB = confusion_matrix(y_test1, y_pred1_GB) / len(y_test1)

print("Confusion Matrix:")
print(conf_matrix1_GB)
# Out:
# Confusion Matrix:
# [[0.61271626 0.00061474]
#  [0.00079037 0.38587863]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier1_C = GradientBoostingClassifier(n_estimators=100)

gb_classifier1_C.fit(X_train1_C, y_train1_C)

y_pred1_GB_C = gb_classifier1_C.predict(X_test1_C)

conf_matrix1_GB_C = confusion_matrix(y_test1_C, y_pred1_GB_C) / len(y_test1_C)

print("Confusion Matrix:")
print(conf_matrix1_GB_C)
# Out:
# Confusion Matrix:
# [[0.60901797 0.001221  ]
#  [0.00375022 0.38601081]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier2 = GradientBoostingClassifier(n_estimators=100)

gb_classifier2.fit(X_train2, y_train2)

y_pred2_GB = gb_classifier2.predict(X_test2)

conf_matrix2_GB = confusion_matrix(y_test2, y_pred2_GB) / len(y_test2)

print("Confusion Matrix:")
print(conf_matrix2_GB)
# Out:
# Confusion Matrix:
# [[0.60642782 0.00131718]
#  [0.00456621 0.3876888 ]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier2_C = GradientBoostingClassifier(n_estimators=100)

gb_classifier2_C.fit(X_train2_C, y_train2_C)

y_pred2_GB_C = gb_classifier2_C.predict(X_test2_C)

conf_matrix2_GB_C = confusion_matrix(y_test2_C, y_pred2_GB_C) / len(y_test2_C)

print("Confusion Matrix:")
print(conf_matrix2_GB_C)
# Out:
# Confusion Matrix:
# [[0.56773688 0.04411381]
#  [0.0027843  0.385365  ]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier3 = GradientBoostingClassifier(n_estimators=100)

gb_classifier3.fit(X_train3, y_train3)

y_pred3_GB = gb_classifier3.predict(X_test3)

conf_matrix3_GB = confusion_matrix(y_test3, y_pred3_GB) / len(y_test3)

print("Confusion Matrix:")
print(conf_matrix3_GB)
# Out:
# Confusion Matrix:
# [[6.09369527e-01 1.75131349e-04]
#  [6.12959720e-04 3.89842382e-01]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier3_C = GradientBoostingClassifier(n_estimators=100)

gb_classifier3_C.fit(X_train3_C, y_train3_C)

y_pred3_GB_C = gb_classifier3_C.predict(X_test3_C)

conf_matrix3_GB_C = confusion_matrix(y_test3_C, y_pred3_GB_C) / len(y_test3_C)

print("Confusion Matrix:")
print(conf_matrix3_GB_C)
# Out:
# Confusion Matrix:
# [[6.09289380e-01 8.69792120e-05]
#  [7.82812908e-04 3.89840828e-01]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier4 = GradientBoostingClassifier(n_estimators=100)

gb_classifier4.fit(X_train4, y_train4)

y_pred4_GB = gb_classifier4.predict(X_test4)

conf_matrix4_GB = confusion_matrix(y_test4, y_pred4_GB) / len(y_test4)

print("Confusion Matrix:")
print(conf_matrix4_GB)
# Out:
# Confusion Matrix:
# [[0.57187855 0.03228629]
#  [0.00629976 0.38953539]]

# %%
# implement basic BDT
from sklearn.ensemble import GradientBoostingClassifier
gb_classifier4_C = GradientBoostingClassifier(n_estimators=100)

gb_classifier4_C.fit(X_train4_C, y_train4_C)

y_pred4_GB_C = gb_classifier4_C.predict(X_test4_C)

conf_matrix4_GB_C = confusion_matrix(y_test4_C, y_pred4_GB_C) / len(y_test4_C)

print("Confusion Matrix:")
print(conf_matrix4_GB_C)
# Out:
# Confusion Matrix:
# [[0.56725756 0.04344804]
#  [0.0021724  0.387122  ]]

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier1 = LinearDiscriminantAnalysis()
qda_classifier1 = QuadraticDiscriminantAnalysis()

lda_classifier1.fit(X_train1, y_train1)
qda_classifier1.fit(X_train1, y_train1)

y_pred1_LDA = lda_classifier1.predict(X_test1)
y_pred1_QDA = qda_classifier1.predict(X_test1)

conf_matrix1_LDA = confusion_matrix(y_test1, y_pred1_LDA) / len(y_test1)
conf_matrix1_QDA = confusion_matrix(y_test1, y_pred1_QDA) / len(y_test1)

print("Confusion Matrix:")
print(conf_matrix1_LDA)
print("Confusion Matrix:")
print(conf_matrix1_QDA)
# Out:
# Confusion Matrix:
# [[0.60665671 0.00667428]
#  [0.00175639 0.38491262]]
# Confusion Matrix:
# [[0.61333099 0.        ]
#  [0.00684992 0.37981909]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier1_C = LinearDiscriminantAnalysis()
qda_classifier1_C = QuadraticDiscriminantAnalysis()

lda_classifier1_C.fit(X_train1_C, y_train1_C)
qda_classifier1_C.fit(X_train1_C, y_train1_C)

y_pred1_LDA_C = lda_classifier1_C.predict(X_test1_C)
y_pred1_QDA_C = qda_classifier1_C.predict(X_test1_C)

conf_matrix1_LDA_C = confusion_matrix(y_test1_C, y_pred1_LDA_C) / len(y_test1_C)
conf_matrix1_QDA_C = confusion_matrix(y_test1_C, y_pred1_QDA_C) / len(y_test1_C)

print("Confusion Matrix:")
print(conf_matrix1_LDA_C)
print("Confusion Matrix:")
print(conf_matrix1_QDA_C)
# Out:
# Confusion Matrix:
# [[0.60230246 0.00793651]
#  [0.0030525  0.38670853]]
# Confusion Matrix:
# [[0.61023897 0.        ]
#  [0.00924472 0.38051631]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier2 = LinearDiscriminantAnalysis()
qda_classifier2 = QuadraticDiscriminantAnalysis()

lda_classifier2.fit(X_train2, y_train2)
qda_classifier2.fit(X_train2, y_train2)

y_pred2_LDA = lda_classifier2.predict(X_test2)
y_pred2_QDA = qda_classifier2.predict(X_test2)

conf_matrix2_LDA = confusion_matrix(y_test2, y_pred2_LDA) / len(y_test2)
conf_matrix2_QDA = confusion_matrix(y_test2, y_pred2_QDA) / len(y_test2)

print("Confusion Matrix:")
print(conf_matrix2_LDA)
print("Confusion Matrix:")
print(conf_matrix2_QDA)
# Out:
# Confusion Matrix:
# [[0.60502283 0.00272216]
#  [0.03784686 0.35440815]]
# Confusion Matrix:
# [[6.07657183e-01 8.78117316e-05]
#  [6.14682122e-03 3.86108184e-01]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier2_C = LinearDiscriminantAnalysis()
qda_classifier2_C = QuadraticDiscriminantAnalysis()

lda_classifier2_C.fit(X_train2_C, y_train2_C)
qda_classifier2_C.fit(X_train2_C, y_train2_C)

y_pred2_LDA_C = lda_classifier2_C.predict(X_test2_C)
y_pred2_QDA_C= qda_classifier2_C.predict(X_test2_C)

conf_matrix2_LDA_C = confusion_matrix(y_test2_C, y_pred2_LDA_C) / len(y_test2_C)
conf_matrix2_QDA_C = confusion_matrix(y_test2_C, y_pred2_QDA_C) / len(y_test2_C)

print("Confusion Matrix:")
print(conf_matrix2_LDA_C)
print("Confusion Matrix:")
print(conf_matrix2_QDA_C)
# Out:
# Confusion Matrix:
# [[0.50126164 0.11058905]
#  [0.01783694 0.37031236]]
# Confusion Matrix:
# [[6.11676673e-01 1.74018968e-04]
#  [1.62707735e-01 2.25441573e-01]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier3 = LinearDiscriminantAnalysis()
qda_classifier3 = QuadraticDiscriminantAnalysis()

lda_classifier3.fit(X_train3, y_train3)
qda_classifier3.fit(X_train3, y_train3)

y_pred3_LDA = lda_classifier3.predict(X_test3)
y_pred3_QDA = qda_classifier3.predict(X_test3)

conf_matrix3_LDA = confusion_matrix(y_test3, y_pred3_LDA) / len(y_test3)
conf_matrix3_QDA = confusion_matrix(y_test3, y_pred3_QDA) / len(y_test3)

print("Confusion Matrix:")
print(conf_matrix3_LDA)
print("Confusion Matrix:")
print(conf_matrix3_QDA)
# Out:
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Confusion Matrix:
# [[6.09369527e-01 1.75131349e-04]
#  [1.31348511e-03 3.89141856e-01]]
# Confusion Matrix:
# [[6.09369527e-01 1.75131349e-04]
#  [1.75131349e-04 3.90280210e-01]]

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier3_C = LinearDiscriminantAnalysis()
qda_classifier3_C = QuadraticDiscriminantAnalysis()

lda_classifier3_C.fit(X_train3_C, y_train3_C)
qda_classifier3_C.fit(X_train3_C, y_train3_C)

y_pred3_LDA_C = lda_classifier3_C.predict(X_test3_C)
y_pred3_QDA_C = qda_classifier3_C.predict(X_test3_C)

conf_matrix3_LDA_C = confusion_matrix(y_test3_C, y_pred3_LDA_C) / len(y_test3_C)
conf_matrix3_QDA_C = confusion_matrix(y_test3_C, y_pred3_QDA_C) / len(y_test3_C)

print("Confusion Matrix:")
print(conf_matrix3_LDA_C)
print("Confusion Matrix:")
print(conf_matrix3_QDA_C)
# Out:
# Confusion Matrix:
# [[0.60850657 0.00086979]
#  [0.00756719 0.38305645]]
# Confusion Matrix:
# [[6.08767505e-01 6.08854484e-04]
#  [5.21875272e-04 3.90101766e-01]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier4 = LinearDiscriminantAnalysis()
qda_classifier4 = QuadraticDiscriminantAnalysis()

lda_classifier4.fit(X_train4, y_train4)
qda_classifier4.fit(X_train4, y_train4)

y_pred4_LDA = lda_classifier4.predict(X_test4)
y_pred4_QDA = qda_classifier4.predict(X_test4)

conf_matrix4_LDA = confusion_matrix(y_test4, y_pred4_LDA) / len(y_test4)
conf_matrix4_QDA = confusion_matrix(y_test4, y_pred4_QDA) / len(y_test4)

print("Confusion Matrix:")
print(conf_matrix4_LDA)
print("Confusion Matrix:")
print(conf_matrix4_QDA)
# Out:
# Confusion Matrix:
# [[0.59541517 0.00874967]
#  [0.11418322 0.28165194]]
# Confusion Matrix:
# [[0.60416484 0.        ]
#  [0.11243328 0.28340187]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# implement LDA and QDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

lda_classifier4_C = LinearDiscriminantAnalysis()
qda_classifier4_C = QuadraticDiscriminantAnalysis()

lda_classifier4_C.fit(X_train4_C, y_train4_C)
qda_classifier4_C.fit(X_train4_C, y_train4_C)

y_pred4_LDA_C = lda_classifier4_C.predict(X_test4_C)
y_pred4_QDA_C = qda_classifier4_C.predict(X_test4_C)

conf_matrix4_LDA_C = confusion_matrix(y_test4_C, y_pred4_LDA_C) / len(y_test4_C)
conf_matrix4_QDA_C = confusion_matrix(y_test4_C, y_pred4_QDA_C) / len(y_test4_C)

print("Confusion Matrix:")
print(conf_matrix4_LDA_C)
print("Confusion Matrix:")
print(conf_matrix4_QDA_C)
# Out:
# Confusion Matrix:
# [[0.4645464  0.14615919]
#  [0.01425096 0.37504345]]
# Confusion Matrix:
# [[0.6107056  0.        ]
#  [0.28554049 0.10375391]]
# c:\Users\marks\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
